# %%
import numpy as np
import matplotlib.pyplot as plt
import function as func
import sys

# %%
if __name__ == "__main__":

        
    y = func.csv_to_array("../data/ms2840a/result_data/yfactor_result_rebin2MHz.csv")
    fmt_op = "o"
    size_op = 1
    
    fig = plt.subplots(figsize=(16,10))
    plt.errorbar(y["freq"], y["Trx"], yerr = y["Trx_err"], fmt=fmt_op, ms=size_op)
    plt.title("receiver noise")
    plt.xlabel("Frequency [GHz]")
    plt.ylabel(r"$T_{rx}$ [K]")
    plt.grid()
    
    plt.savefig("../result_figure/noise.pdf")

    """
    fig, axes = plt.subplots(2,2,figsize=(16,10))

    ax = axes[0][0]
    ax.errorbar(freq, Gain, yerr = Gain_err, fmt=fmt_op, ms=size_op)
    ax.set_title("")
    ax.set_xlabel("Frequency [GHz]")
    ax.set_ylabel("Gain")
    ax.grid()

    ax = axes[0][1]
    ax.errorbar(freq, Trx, yerr = Trx_err, fmt=fmt_op, ms=size_op)
    ax.set_title("")
    ax.set_xlabel("Frequency [GHz]")
    ax.set_ylabel("Trx [K]")
    ax.grid()

    ax = axes[1][0]
    ax.errorbar(freq, Gain_sub, yerr = Gain_sub_err, fmt=fmt_op, ms=size_op)
    ax.set_title("")
    ax.set_xlabel("Frequency [GHz]")
    ax.set_ylabel("Gain (fin - ini)")
    ax.grid()

    ax = axes[1][1]
    ax.errorbar(freq, Trx_sub, yerr = Trx_sub_err, fmt=fmt_op, ms=size_op)
    ax.set_title("")
    ax.set_xlabel("Frequency [GHz]")
    ax.set_ylabel("Trx (fin - ini) [K]")
    ax.grid()

    fig.tight_layout()
    plt.savefig("../result_figure/yfactor_result.pdf")
    """
