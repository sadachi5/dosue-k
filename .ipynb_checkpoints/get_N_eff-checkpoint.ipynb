# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import sys
import lmfit
from scipy import special
import function as func
from scipy import interpolate

# %%
def gause_model(x, mean, sigma, height):
    return height * np.exp( -1./2. * ((x-mean)/sigma) ** 2.)

def gause_residual(params, x, y, yerr):
    mean = params['mean']
    sigma = params['sigma']
    height = params['height']
    y_model = gause_model(x, mean, sigma, height)
    chi = (y - y_model)/yerr
    a = np.isfinite(chi)
    return chi[a]

# %%
start_freq = 0
return

initial = int(start_freq * 1.e+6 - 250)
final = int(initial + 1.e+5)

pp_div = {
    "m8": [], 
    "m7": [], 
    "m6": [], 
    "m5": [], 
    "m4": [], 
    "m3": [], 
    "m2": [], 
    "m1": [], 
    "0": [], 
    "p1": [], 
    "p2": [], 
    "p3": [], 
    "p4": [], 
    "p5": [], 
    "p6": [], 
    "p7": []
}

for i in range(initial, final, 2000):
    word = list(str(i))
    word.insert(2, ".")
    start = "".join(word)
    print(start)
    
    for j in range(462):
        fr = func.csv_to_array("/data/ms2840a/result_data/null_sample_fit/start_{}GHz_{}.csv".format(start, j))
        for k in fr["P"]/fr["P_err"]:
            num = str(int(np.floor(k)))
            if "-" in num: pp_div["m" + num[1:]].append(k)
            elif num == "0": pp_div["0"].append(k)
            else: pp_div["p" + num].append(k)


for k in pp_div:
    path = "/data/ms2840a/other_data/Neff/p_over_delta_p_of_null/{}GHz_{}.csv".format(start_freq, k)
    with open(path, "w") as f:
        writer = csv.writer(f)
        writer.writerow(["value"])
        for v in pp_div[k]:
            writer.writerow([v])
# Out:
#   File "/tmp/ipykernel_1672228/3981609234.py", line 2
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
all_p = np.array([])
for start in [18, 20, 22, 24, 26]:
    print(start)
    for num in ["m8", "m7", "m6", "m5", "m4", "m3", "m2", "m1", "0", "p1", "p2", "p3", "p4", "p5", "p6", "p7"]:
        path = "/data/ms2840a/other_data/Neff/p_over_delta_p_of_null/{}GHz_{}.csv".format(start, num)
        val = func.csv_to_array(path)
        all_p = np.append(all_p, val["value"])
# Out:
# 18
# 20
# 22
# 24
# 26

# %%
n, bins, hatches = plt.hist(all_p, bins=51, range=(-8, 8))

# %%
plt.figure(figsize=(15,6))
plt.rcParams["font.size"] = 18

ne = np.sqrt(n)
x = np.array([(bins[i] + bins[i+1]) / 2 for i in range(len(n))])
col = "blue"
plt.errorbar(x, n, yerr = ne, capsize=0, fmt='x', markersize=10, ecolor=col, markeredgecolor=col, color=col, label="null sample")

params = lmfit.Parameters()
params.add('mean', value=0.)
params.add('sigma', value=1.)
params.add('height', value=1e+7)

result = lmfit.minimize(gause_residual, params, args=(x, n, ne))
height = result.params["height"].value
mean = result.params["mean"].value
mean_err = result.params["mean"].stderr
sigma = result.params["sigma"].value
sigma_err = result.params["sigma"].stderr
plt.plot(x, gause_model(x, mean, sigma, height), label="fit result", color="r")

#plt.text(0.4, 0.21, "rms = " + str(round(np.std(P/P_err), 3)), transform=ax.transAxes)
plt.text(-8, 1e+7, "mean = " + str(round(np.abs(mean), 3)) + r"$\pm$" + str(round(mean_err, 3)))
plt.text(-8, 1.2e+6, "sigma = " + str(round(sigma, 3)) + r"$\pm$" + str(round(sigma_err, 3)))

plt.yscale("log")
plt.legend()
plt.yticks([1, 100, 1e+4, 1e+6])
plt.ylim([0.4, 1e+8])
plt.grid()
plt.xlabel(r"$P_{\rm DP}/\Delta P_{\rm DP}$")
plt.ylabel("counts")
plt.title(r"null sample fit result of $P_{\rm DP}/\Delta P_{\rm DP}$")
plt.savefig("../result_figure/N_eff/null_sample_pop.pdf")

# %%
np.sum(n)
# Out:
# 115500000.0

# %%
N_fit = 115500000

def get_p_local(value):
    num = int(np.floor(value))
    key = ["m8", "m7", "m6", "m5", "m4", "m3", "m2", "m1", "0", "p1", "p2", "p3", "p4", "p5", "p6", "p7"]
    
    print(num)
    print(key[num+9])
    
    left = 0
    for start in ["18", "20", "22", "24", "26"]:
        for i in range(num+9):
            path = "/data/ms2840a/other_data/Neff/p_over_delta_p_of_null/{}GHz_{}.csv".format(start, key[i])
            data = func.csv_to_array(path)
            left += len(data["value"])
    
    for start in ["18", "20", "22", "24", "26"]:
        path = "/data/ms2840a/other_data/Neff/p_over_delta_p_of_null/{}GHz_{}.csv".format(start, key[num+10])
        data = func.csv_to_array(path)
        for d in data["value"]:
            if d < value:
                left += 1
    
    return (N_fit - left)/N_fit

# %%
print(get_p_local(0))
# Out:
# 0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_1672228/1963584813.py in <module>
# ----> 1 print(get_p_local(0))
#
# /tmp/ipykernel_1672228/2563972711.py in get_p_local(value)
#       4     num = int(np.floor(value))
#       5     print(num)
# ----> 6     print(key[num+9])
#       7     key = ["m8", "m7", "m6", "m5", "m4", "m3", "m2", "m1", "0", "p1", "p2", "p3", "p4", "p5", "p6", "p7"]
#       8
#
# UnboundLocalError: local variable 'key' referenced before assignment

# %%
plt.figure(figsize=(15,6))
plt.rcParams["font.size"] = 18

local_P = (1. - special.erf(P/P_err/math.pow(2., 1./2.)))/2.

plt.hist(pp, bins=51, range=(-8, 8))
plt.grid()
plt.xlabel(r"$P_{\rm DP}/\Delta P_{\rm DP}$")
plt.ylabel("counts")
plt.title(r"null sample fit result of $P_{\rm DP}/\Delta P_{\rm DP}$")
plt.yscale("log")

# %%
data = func.csv_to_array("/data/ms2840a/other_data/Neff/p_local_min.csv")

# %%
def make_plot_data(p):
    M = 462*50 # of null samples
    x = np.array([10**-10])
    n = 1.0*len(np.where(p<x[0])[0])
    y = n/M
    ye = np.sqrt(n)/M
    while (x[-1]<0.1): 
        xx = x[-1]*2.73
        n = 1.0*len(np.where(p<xx)[0])
        yy = n/M
        yye = np.sqrt(n)/M
        x = np.append(x, xx)
        y = np.append(y, yy)
        ye = np.append(ye, yye)
        pass
    xe = np.array([0.0]*len(x))
    return (x, y, xe, ye)

# %%
def fit_func(x, u, N):
    return u * np.power(N, 2) * np.power(1-x, u*N-1)

def residual(params, x, y, ye, N):
    u = params['u']
    y_model = fit_func(x, u, N)
    chi = (y - y_model)/ye
    o = np.isfinite(chi)
    return chi[o]

def fit_Neff(x, y, ye, N):    
    params = lmfit.Parameters()
    params.add('u', value=1.)

    result = lmfit.minimize(residual, params, args=(x, y, ye, N))
    u = result.params["u"].value
    ue = result.params["u"].stderr
    
    print("mu = " + str(round(u, 3)) + " +/- " + str(round(ue, 3)))
    print(u)
    print(result.success)
    print(result.redchi)
    
    return fit_func(x, u, N)

# %%
def plot_neff_hist(ax, f, data):
    n, bins, hatches = ax.hist(np.log10(data[f]), bins=51, range=(-10, 0), color="white")
    ne = np.sqrt(n)
    x = np.array([(bins[i] + bins[i+1]) / 2 for i in range(len(n))])
    ax.errorbar(x, n, yerr = ne, capsize=0, fmt='x', markersize=10, ecolor='red', markeredgecolor = "red", color='red', label='p-local min')
    
    
    y = fit_func(10**x, 1, N)
    ax.errorbar(x, y, yerr=0, fmt='x', markersize=10, ecolor='blue', markeredgecolor = "blue", color='blue', label=r'$\mu = 1$')
    
    y = fit_Neff(10**x, n, ne, N)
    ax.errorbar(x, y, yerr=0, fmt='x', markersize=10, ecolor='green', markeredgecolor = "green", color='green', label='fit result')
    
    ax.grid()
    ax.legend()
    ax.set_ylim([0.6, 1.5e+4])
    ax.set_yscale("log")
    ax.set_xlabel(r"$\log_{10}(p_{\rm local-min})$")
    ax.set_ylabel("counts")
    ax.set_title("{} - {} GHz".format(float(f), float(f)+0.1))

# %%
N = 1000

fig, axes = plt.subplots(2,3,figsize=(16,10), squeeze=False)

plot_neff_hist(axes[0][0], "18", data)
plot_neff_hist(axes[0][1], "20", data)
plot_neff_hist(axes[0][2], "22", data)
plot_neff_hist(axes[1][0], "24", data)
plot_neff_hist(axes[1][1], "26", data)

fig.tight_layout()
# Out:
# mu = 0.0 +/- 0.0
# 4.667520757931662e-06
# True
# 1535.0110811842173
# mu = 0.0 +/- 0.0
# 5.910047443875783e-06
# True
# 1643.653927270171
# mu = 0.0 +/- 0.0
# 9.6582617984133e-06
# True
# 1639.6291792922868
# mu = 0.0 +/- 0.0
# 6.137686112789449e-06
# True
# 1533.439678621397
# mu = 0.0 +/- 0.0
# 5.252819008298376e-06
# True
# 1534.362071328716

# %%
def integral_func(x, u):
    return u * 1e+6 * (1 - x)**(u*1000 - 1)

xt = np.array([1e-8 * (i + 1) * 2.73 for i in range(500000)])

plt.plot(xt, integral_func(xt, 1)*xt*2.73, label=r"$\mu = 1$")

plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()

# %%
plt.figure(figsize=(15,6))
plt.errorbar(np.array(freq), np.array(n_eff)/1000, yerr = np.array(n_eff_err)/1000, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
plt.grid()
plt.xlabel("Frequency [GHz]")
plt.title(r"$\mu = N_{\rm eff}/N$")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1634559/1779599378.py in <module>
#       1 plt.figure(figsize=(15,6))
# ----> 2 plt.errorbar(np.array(freq), np.array(n_eff)/1000, yerr = np.array(n_eff_err)/1000, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
#       3 plt.grid()
#       4 plt.xlabel("Frequency [GHz]")
#       5 plt.title(r"$\mu = N_{\rm eff}/N$")
#
# NameError: name 'freq' is not defined

# %%
def fit_line(x, a, b):
    return a * x + b

def residual_line(params, x, y, ye):
    a = params['a']
    b = params['b']
    y_model = fit_line(x, a, b)
    chi = (y - y_model)/ye
    o = np.isfinite(chi)
    return chi[o]

def fit_Neff_line(x, y, ye):    
    params = lmfit.Parameters()
    params.add('a', value=1.)
    params.add('b', value=1.)

    result = lmfit.minimize(residual_line, params, args=(x, y, ye))
    a = result.params["a"].value
    ae = result.params["a"].stderr
    b = result.params["b"].value
    be = result.params["b"].stderr
    
    print("a = " + str(round(a, 3)) + " +/- " + str(round(ae, 3)))
    print("b = " + str(round(b, 3)) + " +/- " + str(round(be, 3)))
    
    return fit_line(x, a, b), ((ae*x)**2 + be**2)**0.5

# %%
l, le = fit_Neff_line(np.array([18, 22, 26]), np.array(n_eff)/1000, np.array(n_eff_err)/1000)
print(np.array(n_eff)/1000)

plt.figure(figsize=(15,6))
plt.errorbar(np.array([18, 22, 26]), np.array(n_eff)/1000, yerr = np.array(n_eff_err)/1000, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
plt.plot(np.array(freq), l)
plt.grid()
plt.xlabel("Frequency [GHz]")
plt.title(r"$\mu = N_{\rm eff}/N$")
plt.savefig("../result_figure/N_eff/fit_line.pdf")
# Out:
# a = -0.0 +/- 0.004
# b = 0.788 +/- 0.137
# [0.78823381]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1506222/79334553.py in <module>
#       3
#       4 plt.figure(figsize=(15,6))
# ----> 5 plt.errorbar(np.array([18, 22, 26]), np.array(n_eff)/1000, yerr = np.array(n_eff_err)/1000, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
#       6 plt.plot(np.array(freq), l)
#       7 plt.grid()
#
# ~/test/lib/python3.8/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2507         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2508         capthick=None, *, data=None, **kwargs):
# -> 2509     return gca().errorbar(
# ...

# %%
freq = []
Neff = []
Neff_err = []

for start_freq in [18, 22, 26]:
    initial = int(start_freq * 1.e+6 - 250)
    final = int(initial + 1.e+5)

    for j in range(initial, final, 2000):
        word = list(str(j))
        word.insert(2, ".")
        start = "".join(word)
        print(start)
        results = {"local": np.array([]), "local_min": np.array([])}

        for k in range(462):
            signal = func.csv_to_array("/data/ms2840a/result_data/null_sample_fit/start_{}GHz_{}.csv".format(start, k))
            local_P = (1. - special.erf(signal["P"]/signal["P_err"]/np.power(2., 1./2.)))/2.
            results["local"] = np.append(results["local"], local_P)
            results["local_min"] = np.append(results["local_min"], np.min(local_P))


        fig, axes = plt.subplots(1,2,figsize=(10,4), squeeze=False)

        ax = axes[0][0]
        ax.hist(np.log10(results["local_min"]), bins=21, range=(-10, 0), histtype='bar', color='red', label='p-local min')
        ax.hist(np.log10(results["local"]), bins=21, range=(-10, 0), histtype='step', color='blue', label='p-local')

        ax.set_xlabel('log scale')
        ax.set_ylabel('Entries')
        ax.set_title("{} GHz".format(round(float(start) + 0.000250, 2)))
        ax.legend(loc="upper left")
        ax.set_yscale('log')


        ax = axes[0][1]
        (x,y,xe,ye) = make_plot_data(results["local_min"])

        Nbins = 1000
        yy = 1 - (1-x)**Nbins

        ax.plot(x, yy, color='black', label='Neff = N')
        ax.errorbar(x, y, yerr = ye, xerr = xe, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red', label='local_min')

        y, ye, N, Ne = fit_Neff(x, y, ye)
        freq.append(float(start))
        Neff.append(N)
        Neff_err.append(Ne)
        ax.errorbar(x, y, yerr = ye, capsize=0, fmt='+', markersize=6, ecolor='green', markeredgecolor = "green", color='green', label='fit')

        x,y,xe,ye = make_plot_data(results["local"])
        ax.errorbar(x, y, yerr = ye, xerr = xe, capsize=0, fmt='x', markersize=6, ecolor='blue', markeredgecolor = "blue", color='blue', label='local')

        ax.set_xlabel('p-local')
        ax.set_ylabel('p-global')
        #ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_ylim(Nbins*10**-10, 5*10**0)
        ax.grid()
        ax.legend(loc='upper left')

        fig.tight_layout()
        
        break
        
    break
        
plt.figure(figsize=(15,6))
plt.errorbar(freq, Neff, yerr = Neff_err, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
plt.grid()
plt.xlabel("Frequency [GHz]")
plt.title("Neff")
# Out:
# 17.999750
# Text(0.5, 1.0, 'Neff')

# %%
plt.figure(figsize=(15,6))
plt.errorbar(np.array(freq), np.array(Neff)/1000, yerr = np.array(Neff_err)/1000, capsize=0, fmt='o', markersize=5, ecolor='red', markeredgecolor = "red", color='red')
plt.grid()
plt.xlabel("Frequency [GHz]")
plt.title(r"$\mu = N_{\rm eff}/N$")
# Out:
# Text(0.5, 1.0, '$\\mu = N_{\\rm eff}/N$')

# %%
freq = np.array()
