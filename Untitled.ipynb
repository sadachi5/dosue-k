# %%
import numpy as np
import matplotlib.pyplot as plt
import function as func
import sys

# %%
for i in range(180, 264, 1):
    word = list(str(i))
    word.insert(2, ".")
    start_freq = float("".join(word))
    print(start_freq)
    
    path = "/data/ms2840a/result_data/yfactor_result/start_{}GHz.csv".format(str(start_freq))
    y = func.csv_to_array(path)
    n = len(y["freq"])**0.5
    print(n)
    print(len(y["freq"]))
    print(" &", np.round(np.mean(y["Gain_ini"])/1e6, 4), "$\pm$", np.round(np.mean(y["Gain_ini_err"]**2)**0.5/n/1e6, 4), "&", np.round(np.mean(y["Trx_ini"]),1), "$\pm$", np.round(np.mean(y["Trx_ini_err"]**2)**0.5/n,2))
    print(" &", np.round(np.mean(y["Gain_fin"])/1e6, 3), "$\pm$", np.round(np.mean(y["Gain_fin_err"])/1e6, 4), "&", np.round(np.mean(y["Trx_fin"]),1), "$\pm$", np.round(np.mean(y["Trx_fin_err"]),2))
    #print(np.round(np.mean(y["Gain"])), np.round(np.mean(y["Gain_err"])), np.round(np.mean(y["Trx"]),2), np.round(np.mean(y["Trx_err"]),2))
    print()
    
    #18.0
    # & 2.259 $\pm$ 0.0019 & 160.1 $\pm$ 0.26
    # & 2.263 $\pm$ 0.0019 & 159.8 $\pm$ 0.26
# Out:
# 18.0
# 7.0710678118654755
# 50
#  & 2.2586 $\pm$ 0.0002 & 155.8 $\pm$ 0.04
#  & 2.263 $\pm$ 0.0017 & 155.5 $\pm$ 0.29
#
# 18.1
# 7.0710678118654755
# 50
#  & 2.3621 $\pm$ 0.0003 & 159.4 $\pm$ 0.04
#  & 2.367 $\pm$ 0.002 & 159.3 $\pm$ 0.26
#
# 18.2
# 7.0710678118654755
# 50
#  & 2.4023 $\pm$ 0.0003 & 157.0 $\pm$ 0.04
#  & 2.394 $\pm$ 0.002 & 159.3 $\pm$ 0.26
#
# 18.3
# 7.0710678118654755
# 50
#  & 2.3246 $\pm$ 0.0003 & 161.8 $\pm$ 0.04
#  & 2.322 $\pm$ 0.002 & 164.6 $\pm$ 0.27
#
# 18.4
# 7.0710678118654755
# 50
#  & 2.398 $\pm$ 0.0003 & 170.1 $\pm$ 0.04
#  & 2.408 $\pm$ 0.0021 & 168.3 $\pm$ 0.28
#
# 18.5
# 7.0710678118654755
# 50
#  & 2.301 $\pm$ 0.0003 & 173.4 $\pm$ 0.04
#  & 2.303 $\pm$ 0.002 & 172.7 $\pm$ 0.28
#
# 18.6
# 7.0710678118654755
# 50
#  & 2.3669 $\pm$ 0.0003 & 174.7 $\pm$ 0.04
#  & 2.367 $\pm$ 0.0021 & 173.6 $\pm$ 0.29
#
# 18.7
# 7.0710678118654755
# 50
#  & 2.4047 $\pm$ 0.0003 & 176.3 $\pm$ 0.04
#  & 2.408 $\pm$ 0.0021 & 176.4 $\pm$ 0.29
#
# 18.8
# 7.0710678118654755
# ...

# %%
for i in range(180, 264, 1):
    word = list(str(i))
    word.insert(2, ".")
    start_freq = float("".join(word))
    print(start_freq)
    
    path = "/data/ms2840a/result_data/yfactor_result/start_{}GHz.csv".format(str(start_freq))
    y = func.csv_to_array(path)
    print(" &", np.round(np.mean(y["Gain_ini"])/1e6, 3), "$\pm$", np.round(np.mean(y["Gain_ini_err"])/1e6, 4), "&", np.round(np.mean(y["Trx_ini"]),1), "$\pm$", np.round(np.mean(y["Trx_ini_err"]),2))
    print(" &", np.round(np.mean(y["Gain_fin"])/1e6, 3), "$\pm$", np.round(np.mean(y["Gain_fin_err"])/1e6, 4), "&", np.round(np.mean(y["Trx_fin"]),1), "$\pm$", np.round(np.mean(y["Trx_fin_err"]),2))
    #print(np.round(np.mean(y["Gain"])), np.round(np.mean(y["Gain_err"])), np.round(np.mean(y["Trx"]),2), np.round(np.mean(y["Trx_err"]),2))
    print()
